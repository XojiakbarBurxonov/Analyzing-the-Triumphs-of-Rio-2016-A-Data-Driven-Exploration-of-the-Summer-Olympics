# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("summer2016.csv")
df.head()
# Out:
#    Unnamed: 0   ID                         Name Sex   Age  Height  Weight  \
# 0         158   62            Giovanni Abagnale   M  21.0   198.0    90.0
# 1         161   65            Patimat Abakarova   F  21.0   165.0    49.0
# 2         175   73                    Luc Abalo   M  31.0   182.0    86.0
# 3         450  250         Saeid Morad Abdevali   M  26.0   170.0    80.0
# 4         794  455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
#
#          Team  NOC        Games  Year  Season            City       Sport  \
# 0       Italy  ITA  2016 Summer  2016  Summer  Rio de Janeiro      Rowing
# 1  Azerbaijan  AZE  2016 Summer  2016  Summer  Rio de Janeiro   Taekwondo
# 2      France  FRA  2016 Summer  2016  Summer  Rio de Janeiro    Handball
# 3        Iran  IRI  2016 Summer  2016  Summer  Rio de Janeiro   Wrestling
# 4      Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                                        Event   Medal
# ...

# %%
men_rowing=df[(df['Sex']=='M') &(df['Sport']=='Rowing')]
men_rowing['Sex'].value_counts()
# Out:
# Sex
# M    84
# Name: count, dtype: int64

# %%
df['Sport'].value_counts()
# Out:
# Sport
# Swimming                 190
# Athletics                188
# Rowing                   144
# Football                 105
# Hockey                    99
# Handball                  89
# Cycling                   84
# Canoeing                  82
# Water Polo                78
# Rugby Sevens              74
# Basketball                72
# Volleyball                72
# Wrestling                 72
# Gymnastics                66
# Fencing                   65
# Judo                      56
# Boxing                    51
# Sailing                   45
# Shooting                  45
# Equestrianism             45
# Weightlifting             45
# Diving                    36
# Taekwondo                 32
# Synchronized Swimming     32
# Tennis                    24
# Table Tennis              24
# Archery                   24
# Badminton                 23
# Rhythmic Gymnastics       18
# Beach Volleyball          12
# Triathlon                  6
# Modern Pentathlon          6
# ...

# %%
men_gymnastics=df[(df['Sex']=='M') &(df['Sport']=='Gymnastics')]
men_gymnastics['Sex'].value_counts()
# Out:
# Sex
# M    36
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.bar('Rowing', men_rowing['Height'].mean())
ax.bar('Gymnastics', men_gymnastics['Height'].mean())
ax.set_ylabel("Height (cm)")
plt.show()

# %% [markdown]
# # Introducing histograms

# %%
fig, ax = plt.subplots()
ax.hist(df_rowing['Height'],label='Rowing')
ax.hist(df_gymnastics['Height'], label='Gymnastics')
ax.set_title("Men's Height: Rowing vs. Gymnastics, Rio 2016")
ax.set_xlabel("Height (cm)")
ax.set_ylabel("# of observations")
ax.legend()
plt.show()

# %% [markdown]
# # Customizing histograms: setting bin boundaries

# %%
fig, ax = plt.subplots()
ax.hist(df_rowing['Height'],label='Rowing',bins=[150, 160, 170, 180, 190, 200, 210])
ax.hist(df_gymnastics['Height'], label='Gymnastics', bins=[150, 160, 170, 180, 190, 200, 210])
ax.set_title("Men's Height: Rowing vs. Gymnastics, Rio 2016")
ax.set_xlabel("Height (cm)")
ax.set_ylabel("# of observations")
ax.legend()
plt.show()

# %% [markdown]
# # Customizing histograms: Transparency

# %%
fig, ax = plt.subplots()
ax.hist(df_rowing['Height'],label='Rowing',bins=[150, 160, 170, 180, 190, 200, 210], histtype='step')
ax.hist(df_gymnastics['Height'], label='Gymnastics', bins=[150, 160, 170, 180, 190, 200, 210], histtype='step')
ax.set_title("Men's Height: Rowing vs. Gymnastics, Rio 2016")
ax.set_xlabel("Height (cm)")
ax.set_ylabel("# of observations")
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
# Plot a histogram of "Weight" for mens_rowing
ax.hist(men_rowing['Weight'])

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(men_gymnastics['Weight'])

# Set the x-axis label to "Weight (kg)"
ax.set_xlabel("Weight (kg)")

# Set the y-axis label to "# of observations"
ax.set_ylabel("# of observations")

plt.show()

# %% [markdown]
# Nice. Now let's customize these histograms a bit by changing their default settings.

# %%
fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing
ax.hist(men_rowing['Weight'], label = 'Rowing', histtype = 'step', bins = 5)

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(men_gymnastics['Weight'],label = 'Gymnastics', histtype='step',bins = 5)

ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")

# Add the legend and show the Figure
ax.legend()
plt.show()

# %% [markdown]
# Well done! Let's see how to use these distributions in statistical plots.

# %% [markdown]
# # Statistical plotting

# %% [markdown]
# #### Adding error bars to bar charts

# %%
fig, ax = plt.subplots()
ax.bar('Rowing', men_rowing['Height'].mean(),
       yerr=men_rowing['Height'].std())

ax.bar('Gymnastics', men_gymnastics['Height'].mean(),
       yerr=men_gymnastics['Height'].std())
ax.set_ylabel("Height (cm)")
plt.show()

# %% [markdown]
# That's great! These error bars can help you see that the difference in heights is rather large in terms of the standard deviation within every group.

# %% [markdown]
# # Adding boxplots

# %%
plt.style.use('bmh')
fig, ax = plt.subplots()
ax.boxplot([men_rowing['Height'],men_gymnastics['Height']])
ax.set_xticklabels(["Rowing","Gymnastics"])
ax.set_ylabel("Height (cm)")
plt.show()

# %% [markdown]
# Very good. This provides even more information. For example, we can see how many individuals are outliers within their group. Next, let's see how we compare two variables within a single sample.

# %%
sports = df['Sport'].unique()
sports
# Out:
# array(['Rowing', 'Taekwondo', 'Handball', 'Wrestling', 'Gymnastics',
#        'Swimming', 'Basketball', 'Boxing', 'Volleyball', 'Athletics',
#        'Rugby Sevens', 'Judo', 'Rhythmic Gymnastics', 'Weightlifting',
#        'Equestrianism', 'Badminton', 'Water Polo', 'Football', 'Fencing',
#        'Shooting', 'Sailing', 'Beach Volleyball', 'Canoeing', 'Hockey',
#        'Cycling', 'Tennis', 'Diving', 'Table Tennis', 'Triathlon',
#        'Archery', 'Synchronized Swimming', 'Modern Pentathlon',
#        'Trampolining', 'Golf'], dtype=object)

# %% [markdown]
# ### Bar-charts of Heights for all sports

# %%
fig, ax  =plt.subplots(figsize=(10,6))
for sport in sports:
    sports_df= df[df['Sport']==sport]
    ax.bar(sport, sports_df['Height'].mean(), yerr=sports_df['Height'].std())
ax.set_ylabel("Height (cm)")
ax.set_xticklabels(sports, rotation=90)
plt.show()
# Out:
# /var/folders/25/525jtcfx3d549_lxzx7k_p8m0000gn/T/ipykernel_20033/816085599.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sports, rotation=90)

# %%
fig, ax = plt.subplots()

# Loop over the different sports branches
for sport in sports:
  # Extract the rows only for this sport
  sport_df = df[df['Sport']==sport]
  # Add a bar for the "Weight" mean with std y error bar
  ax.bar(sport, sport_df['Weight'].mean(),yerr= sport_df['Weight'].std())

ax.set_ylabel("Weight")
ax.set_xticklabels(sports, rotation=90)

# Save the figure to file
fig.savefig("sports_weights.png", dpi=300,bbox_inches='tight')
# Out:
# /var/folders/25/525jtcfx3d549_lxzx7k_p8m0000gn/T/ipykernel_20033/1403560380.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sports, rotation=90)
